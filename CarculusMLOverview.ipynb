# %% [markdown]
# ![Carculus1.jpeg](attachment:Carculus1.jpeg)

# %% [markdown]
# ![Carculus2.jpeg](attachment:Carculus2.jpeg)

# %% [markdown]
# ![carculus_model_plot.png](attachment:carculus_model_plot.png)

# %% [markdown]
# <div class="cfc-flex-wrap-container ng-star-inserted"><!----><tables-model-card class="cfc-container-item ng-star-inserted"><auto-ml-model-card><!----><cfc-info-card nghost-lyv-c230="" class="cfc-info-card ng-star-inserted"><div _ngcontent-lyv-c230="" class="cfc-info-card-styling"><cfc-info-card-header _nghost-lyv-c237=""><div _ngcontent-lyv-c237="" class="cfc-info-card-header-status-container"><div _ngcontent-lyv-c237="" class="cfc-info-card-header-status"></div></div><div _ngcontent-lyv-c237="" class="cfc-info-card-header"><!----><div _ngcontent-lyv-c237="" class="cfc-info-card-header-content"><h2 _ngcontent-lyv-c237="" class="cfc-info-card-header-text"><div header="" class="ng-star-inserted"><h6 id="p6ntest-model-card-type" class="cfc-space-above-minus-6"> Regression model </h6></div><!----><div header="" id="p6ntest-model-card-display-name"> Carculus_Feb24 </div></h2><div _ngcontent-lyv-c237="" class="cfc-info-card-header-metadata"></div></div></div></cfc-info-card-header><div _ngcontent-lyv-c230="" class="cfc-info-card-top-right"></div><div _ngcontent-lyv-c230="" class="cfc-info-card-top-right cfctest-info-card-utility"><div cfc-info-card-utility="" class="ng-star-inserted"><button mat-icon-button="" aria-label="overflow menu" class="mat-focus-indicator mat-icon-button mat-button-base ng-star-inserted" jslog="65831;track:generic_click" aria-expanded="false" aria-haspopup="menu"><span class="mat-button-wrapper"><ace-icon icon="more" class="ace-icon ace-icon-size-small ace-icon-more"><mat-icon role="img" class="mat-icon notranslate mat-icon-no-color ng-star-inserted" aria-hidden="true" data-mat-icon-type="svg" data-mat-icon-name="more" data-mat-icon-namespace="common-small"><svg width="100%" height="100%" viewBox="0 0 18 18" fit="" preserveAspectRatio="xMidYMid meet" focusable="false"><path d="M9 6a2 2 0 1 1 0-4 2 2 0 0 1 0 4zm0 5a2 2 0 1 1 0-4 2 2 0 0 1 0 4zm0 5a2 2 0 1 1 0-4 2 2 0 0 1 0 4z" fill-rule="evenodd"></path></svg></mat-icon><!----><!----><!----><!----></ace-icon></span><span matripple="" class="mat-ripple mat-button-ripple mat-button-ripple-round"></span><span class="mat-button-focus-overlay"></span></button><!----><cfc-menu style="display: none;" class="ng-tns-c208-48 ng-star-inserted"><ace-overlay class="ng-tns-c208-48"><!----></ace-overlay><!----></cfc-menu><!----></div><!----></div><cfc-info-card-body-group _nghost-lyv-c236="" class="ng-star-inserted"><div _ngcontent-lyv-c236="" class="cfc-info-card-body-group"><ai-legacy-banner><!----></ai-legacy-banner><cfc-info-card-item _nghost-lyv-c235=""><div _ngcontent-lyv-c235="" class="cfc-info-card-item-spacer"><!----><div _ngcontent-lyv-c235="" class="cfc-info-card-item cfc-button-small ng-star-inserted" jslog="61943"><div _ngcontent-lyv-c235="" class="cfc-info-card-item-left-gutter ng-star-inserted"></div><!----><div _ngcontent-lyv-c235="" class="cfc-info-card-item-content ng-star-inserted"><div _ngcontent-lyv-c235="" class="cfc-info-card-item-content-left"><!----><div class="cfc-inline-flex-container cfc-width-full ng-star-inserted" style="display: flex; box-sizing: border-box; flex-direction: row;"><div fxflex="50" style="max-width: 50%; flex: 1 1 100%; box-sizing: border-box;"><h6 class="cfc-space-below-minus-6"> MAE <!----><cfc-help-button><button mat-icon-button="" type="button" class="cfc-help-button mdc-icon-button mat-mdc-icon-button mat-unthemed mat-mdc-button-base cm-button ace-tooltip-disable-user-select-on-touch-device cfc-tooltip-disable-user-select-on-touch-device" aria-label="Help popup" jslog="104902;track:generic_click"><span class="mat-mdc-button-persistent-ripple mdc-icon-buttonripple"></span><span class="mdc-buttonlabel"><ace-icon icon="help" size="small" class="ace-icon ace-icon-size-small ace-icon-help"><mat-icon role="img" class="mat-icon notranslate mat-icon-no-color ng-star-inserted" aria-hidden="true" data-mat-icon-type="svg" data-mat-icon-name="help" data-mat-icon-namespace="common-small"><svg width="100%" height="100%" viewBox="0 0 18 18" fit="" preserveAspectRatio="xMidYMid meet" focusable="false"><path d="M9 16A7 7 0 1 0 9 2a7 7 0 0 0 0 14zm2.47-7.587a5.15 5.15 0 0 1-.548.61c-.206.195-.42.387-.64.578-.25.22-.418.37-.503.62-.09.26-.13.78-.14.78H8.08s.02-.48.06-.71a2.09 2.09 0 0 1 .19-.57c.09-.18.207-.34.348-.5A6.1 6.1 0 0 1 9.2 8.7c.156-.14.3-.268.436-.393s.253-.25.356-.382c.103-.13.184-.27.244-.42.06-.147.09-.312.09-.493 0-.4-.106-.702-.32-.913-.21-.21-.524-.32-.936-.32-.165 0-.93-.04-1.2.49-.075.142-.187.49-.187.68H6c.072-.598.178-.91.33-1.21.155-.308.366-.49.633-.7.267-.206.58-.33.94-.43.36-.105.75-.14 1.172-.14.463 0 .874.06 1.236.172.37.11.67.275.92.487.26.21.45.474.58.78.13.305.2.652.2 1.04 0 .28-.042.54-.14.78a2.81 2.81 0 0 1-.383.68zM8.997 14c-.32 0-.565-.094-.738-.284a1.006 1.006 0 0 1-.26-.704c0-.143.02-.276.06-.4a.923.923 0 0 1 .19-.32.868.868 0 0 1 .31-.215A1.11 1.11 0 0 1 8.99 12c.16 0 .3.026.426.077a.83.83 0 0 1 .312.215c.084.09.15.198.196.32.046.124.07.256.07.4 0 .28-.087.516-.26.704-.175.19-.42.284-.74.284z" fill-rule="evenodd"></path></svg></mat-icon><!----><!----><!----><!----></ace-icon></span><span class="mat-mdc-focus-indicator cm-mat-focus-indicator"></span><span matripple="" class="mat-ripple mat-mdc-button-ripple"></span><span class="mat-mdc-button-touch-target"></span></button><!----></cfc-help-button></h6><div><h1> 1,185.821 </h1></div></div><div fxflex="50" style="max-width: 50%; flex: 1 1 100%; box-sizing: border-box;"><!----><h6 class="cfc-space-below-minus-6 ng-star-inserted"> RMSE <!----><cfc-help-button><button mat-icon-button="" type="button" class="cfc-help-button mdc-icon-button mat-mdc-icon-button mat-unthemed mat-mdc-button-base cm-button ace-tooltip-disable-user-select-on-touch-device cfc-tooltip-disable-user-select-on-touch-device" aria-label="Help popup" jslog="104902;track:generic_click"><span class="mat-mdc-button-persistent-ripple mdc-icon-buttonripple"></span><span class="mdc-buttonlabel"><ace-icon icon="help" size="small" class="ace-icon ace-icon-size-small ace-icon-help"><mat-icon role="img" class="mat-icon notranslate mat-icon-no-color ng-star-inserted" aria-hidden="true" data-mat-icon-type="svg" data-mat-icon-name="help" data-mat-icon-namespace="common-small"><svg width="100%" height="100%" viewBox="0 0 18 18" fit="" preserveAspectRatio="xMidYMid meet" focusable="false"><path d="M9 16A7 7 0 1 0 9 2a7 7 0 0 0 0 14zm2.47-7.587a5.15 5.15 0 0 1-.548.61c-.206.195-.42.387-.64.578-.25.22-.418.37-.503.62-.09.26-.13.78-.14.78H8.08s.02-.48.06-.71a2.09 2.09 0 0 1 .19-.57c.09-.18.207-.34.348-.5A6.1 6.1 0 0 1 9.2 8.7c.156-.14.3-.268.436-.393s.253-.25.356-.382c.103-.13.184-.27.244-.42.06-.147.09-.312.09-.493 0-.4-.106-.702-.32-.913-.21-.21-.524-.32-.936-.32-.165 0-.93-.04-1.2.49-.075.142-.187.49-.187.68H6c.072-.598.178-.91.33-1.21.155-.308.366-.49.633-.7.267-.206.58-.33.94-.43.36-.105.75-.14 1.172-.14.463 0 .874.06 1.236.172.37.11.67.275.92.487.26.21.45.474.58.78.13.305.2.652.2 1.04 0 .28-.042.54-.14.78a2.81 2.81 0 0 1-.383.68zM8.997 14c-.32 0-.565-.094-.738-.284a1.006 1.006 0 0 1-.26-.704c0-.143.02-.276.06-.4a.923.923 0 0 1 .19-.32.868.868 0 0 1 .31-.215A1.11 1.11 0 0 1 8.99 12c.16 0 .3.026.426.077a.83.83 0 0 1 .312.215c.084.09.15.198.196.32.046.124.07.256.07.4 0 .28-.087.516-.26.704-.175.19-.42.284-.74.284z" fill-rule="evenodd"></path></svg></mat-icon><!----><!----><!----><!----></ace-icon></span><span class="mat-mdc-focus-indicator cm-mat-focus-indicator"></span><span matripple="" class="mat-ripple mat-mdc-button-ripple"></span><span class="mat-mdc-button-touch-target"></span></button><!----></cfc-help-button></h6><div class="ng-star-inserted"><h1> 1,886.208 </h1></div><!----><!----></div></div><div class="cfc-inline-flex-container cfc-width-full ng-star-inserted" style="display: flex; box-sizing: border-box; flex-direction: row;"><div fxflex="50" style="max-width: 50%; flex: 1 1 100%; box-sizing: border-box;"><h6 class="cfc-space-below-minus-6"> r^2 <!----><cfc-help-button><button mat-icon-button="" type="button" class="cfc-help-button mdc-icon-button mat-mdc-icon-button mat-unthemed mat-mdc-button-base cm-button ace-tooltip-disable-user-select-on-touch-device cfc-tooltip-disable-user-select-on-touch-device" aria-label="Help popup" jslog="104902;track:generic_click"><span class="mat-mdc-button-persistent-ripple mdc-icon-buttonripple"></span><span class="mdc-buttonlabel"><ace-icon icon="help" size="small" class="ace-icon ace-icon-size-small ace-icon-help"><mat-icon role="img" class="mat-icon notranslate mat-icon-no-color ng-star-inserted" aria-hidden="true" data-mat-icon-type="svg" data-mat-icon-name="help" data-mat-icon-namespace="common-small"><svg width="100%" height="100%" viewBox="0 0 18 18" fit="" preserveAspectRatio="xMidYMid meet" focusable="false"><path d="M9 16A7 7 0 1 0 9 2a7 7 0 0 0 0 14zm2.47-7.587a5.15 5.15 0 0 1-.548.61c-.206.195-.42.387-.64.578-.25.22-.418.37-.503.62-.09.26-.13.78-.14.78H8.08s.02-.48.06-.71a2.09 2.09 0 0 1 .19-.57c.09-.18.207-.34.348-.5A6.1 6.1 0 0 1 9.2 8.7c.156-.14.3-.268.436-.393s.253-.25.356-.382c.103-.13.184-.27.244-.42.06-.147.09-.312.09-.493 0-.4-.106-.702-.32-.913-.21-.21-.524-.32-.936-.32-.165 0-.93-.04-1.2.49-.075.142-.187.49-.187.68H6c.072-.598.178-.91.33-1.21.155-.308.366-.49.633-.7.267-.206.58-.33.94-.43.36-.105.75-.14 1.172-.14.463 0 .874.06 1.236.172.37.11.67.275.92.487.26.21.45.474.58.78.13.305.2.652.2 1.04 0 .28-.042.54-.14.78a2.81 2.81 0 0 1-.383.68zM8.997 14c-.32 0-.565-.094-.738-.284a1.006 1.006 0 0 1-.26-.704c0-.143.02-.276.06-.4a.923.923 0 0 1 .19-.32.868.868 0 0 1 .31-.215A1.11 1.11 0 0 1 8.99 12c.16 0 .3.026.426.077a.83.83 0 0 1 .312.215c.084.09.15.198.196.32.046.124.07.256.07.4 0 .28-.087.516-.26.704-.175.19-.42.284-.74.284z" fill-rule="evenodd"></path></svg></mat-icon><!----><!----><!----><!----></ace-icon></span><span class="mat-mdc-focus-indicator cm-mat-focus-indicator"></span><span matripple="" class="mat-ripple mat-mdc-button-ripple"></span><span class="mat-mdc-button-touch-target"></span></button><!----></cfc-help-button></h6><div><h1> 0.987 </h1></div></div><div fxflex="50" style="max-width: 50%; flex: 1 1 100%; box-sizing: border-box;"><h6 class="cfc-space-below-minus-6"> MAPE <!----><cfc-help-button><button mat-icon-button="" type="button" class="cfc-help-button mdc-icon-button mat-mdc-icon-button mat-unthemed mat-mdc-button-base cm-button ace-tooltip-disable-user-select-on-touch-device cfc-tooltip-disable-user-select-on-touch-device" aria-label="Help popup" jslog="104902;track:generic_click"><span class="mat-mdc-button-persistent-ripple mdc-icon-buttonripple"></span><span class="mdc-button_label"><ace-icon icon="help" size="small" class="ace-icon ace-icon-size-small ace-icon-help"><mat-icon role="img" class="mat-icon notranslate mat-icon-no-color ng-star-inserted" aria-hidden="true" data-mat-icon-type="svg" data-mat-icon-name="help" data-mat-icon-namespace="common-small"><svg width="100%" height="100%" viewBox="0 0 18 18" fit="" preserveAspectRatio="xMidYMid meet" focusable="false"><path d="M9 16A7 7 0 1 0 9 2a7 7 0 0 0 0 14zm2.47-7.587a5.15 5.15 0 0 1-.548.61c-.206.195-.42.387-.64.578-.25.22-.418.37-.503.62-.09.26-.13.78-.14.78H8.08s.02-.48.06-.71a2.09 2.09 0 0 1 .19-.57c.09-.18.207-.34.348-.5A6.1 6.1 0 0 1 9.2 8.7c.156-.14.3-.268.436-.393s.253-.25.356-.382c.103-.13.184-.27.244-.42.06-.147.09-.312.09-.493 0-.4-.106-.702-.32-.913-.21-.21-.524-.32-.936-.32-.165 0-.93-.04-1.2.49-.075.142-.187.49-.187.68H6c.072-.598.178-.91.33-1.21.155-.308.366-.49.633-.7.267-.206.58-.33.94-.43.36-.105.75-.14 1.172-.14.463 0 .874.06 1.236.172.37.11.67.275.92.487.26.21.45.474.58.78.13.305.2.652.2 1.04 0 .28-.042.54-.14.78a2.81 2.81 0 0 1-.383.68zM8.997 14c-.32 0-.565-.094-.738-.284a1.006 1.006 0 0 1-.26-.704c0-.143.02-.276.06-.4a.923.923 0 0 1 .19-.32.868.868 0 0 1 .31-.215A1.11 1.11 0 0 1 8.99 12c.16 0 .3.026.426.077a.83.83 0 0 1 .312.215c.084.09.15.198.196.32.046.124.07.256.07.4 0 .28-.087.516-.26.704-.175.19-.42.284-.74.284z" fill-rule="evenodd"></path></svg></mat-icon><!----><!----><!----><!----></ace-icon></span><span class="mat-mdc-focus-indicator cm-mat-focus-indicator"></span><span matripple="" class="mat-ripple mat-mdc-button-ripple"></span><span class="mat-mdc-button-touch-target"></span></button><!----></cfc-help-button></h6><div><h1> 10.1% </h1></div></div></div><!----><!----></div><div _ngcontent-lyv-c235="" class="cfc-align-right"></div></div><!----><!----></div><!----></div><!----></cfc-info-card-item></div></cfc-info-card-body-group><cfc-info-card-body-group _nghost-lyv-c236="" class="ng-star-inserted"><div _ngcontent-lyv-c236="" class="cfc-info-card-body-group"><cfc-info-card-item _nghost-lyv-c235=""><div _ngcontent-lyv-c235="" class="cfc-info-card-item-spacer"><!----><div _ngcontent-lyv-c235="" class="cfc-info-card-item cfc-button-small ng-star-inserted" jslog="61943"><div _ngcontent-lyv-c235="" class="cfc-info-card-item-left-gutter ng-star-inserted"></div><!----><div _ngcontent-lyv-c235="" class="cfc-info-card-item-content ng-star-inserted"><div _ngcontent-lyv-c235="" class="cfc-info-card-item-content-left"><dl ace-kv-list="" class="cfc-space-below-minus-6 ace-kv-list ace-kv-list-hide-pinlines ace-kv-list-key-width-default"><div><dt><div class="cfc-font-weight-regular"> Model ID </div></dt><dd> TBL4268108425956687872 </dd></div><div><dt><div class="cfc-font-weight-regular"> Created on </div></dt><dd> Feb 24, 2022, 12:41:43 AM </dd></div><div><dt><div class="cfc-font-weight-regular"> Target </div></dt><dd> soldpricecad </dd></div><div><dt><div class="cfc-font-weight-regular"> Feature columns </div></dt><dd><a aria-label="Included Columns" class="cfc-external-link ace-tooltip-disable-user-select-on-touch-device cfc-tooltip-disable-user-select-on-touch-device"> 50 included </a></dd></div><div><dt><div class="cfc-font-weight-regular"> Test rows </div></dt><dd> 47,727 </dd></div><!----><div><dt><div class="cfc-font-weight-regular"> Optimization objective </div></dt><dd> MAE </dd></div><div><dt><div class="cfc-font-weight-regular"> Training cost </div></dt><dd> 6 node hours </dd></div><div class="ng-star-inserted"><dt><div class="cfc-font-weight-regular"> Model hyperparameters </div></dt><dd style="display: flex; box-sizing: border-box; flex-direction: row;"><a href="/logs/viewer?advancedFilter=resource.type%3D%22cloudml_job%22%20resource.labels.job_id%3D%22TBL4268108425956687872%22%20resource.labels.project_id%3D%22carculusmodel%22%20labels.log_type%3D%22automl_tables%22%20jsonPayload.%22@type%22%3D%22type.googleapis.com%2Fgoogle.cloud.automl.master.TablesModelStructure%22&amp;interval=NO_LIMIT&amp;authuser=2&amp;project=carculusmodel" rel="noopener"> Model </a><div fxflex="10px" style="max-width: 10px; min-width: 10px; flex: 1 1 10px; box-sizing: border-box;"></div><a href="/logs/viewer?advancedFilter=resource.type%3D%22cloudml_job%22%20resource.labels.job_id%3D%22TBL4268108425956687872%22%20resource.labels.project_id%3D%22carculusmodel%22%20labels.log_type%3D%22automl_tables%22%20jsonPayload.%22@type%22%3D%22type.googleapis.com%2Fgoogle.cloud.automl.master.TuningTrial%22&amp;interval=NO_LIMIT&amp;authuser=2&amp;project=carculusmodel" rel="noopener"> Trials </a></dd></div><!----><div><dt><div class="cfc-font-weight-regular"> Status </div></dt><!----><dd class="ng-star-inserted"> Not deployed </dd><!----></div></dl></div><div _ngcontent-lyv-c235="" class="cfc-align-right"></div></div><!----><!----></div><!----></div><!----></cfc-info-card-item></div></cfc-info-card-body-group><!----><!----><!----><!----><!----><!----><!----><cfc-info-card-footer _nghost-lyv-c231="" class="ng-star-inserted"><div _ngcontent-lyv-c231="" class="cfc-info-card-footer cfc-info-card-footer-with-gutter"><div _ngcontent-lyv-c231="" class="cfc-info-card-item-left-gutter ng-star-inserted"></div><!----><button mat-button="" color="primary" class="mat-focus-indicator cfc-cursor-pointer mat-button mat-button-base mat-primary ng-star-inserted" tabindex="0" rel="noopener"><span class="mat-button-wrapper"> See Full Evaluation </span><span matripple="" class="mat-ripple mat-button-ripple"></span><span class="mat-button-focus-overlay"></span></button><!----><!----></div></cfc-info-card-footer><!----><!----></div></cfc-info-card><!----><!----><!----><!----><!----><!----><!----></auto-ml-model-card><!----></tables-model-card><!----></div>
