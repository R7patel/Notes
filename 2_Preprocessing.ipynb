# %% [markdown]
# # Table of contents
# * [Feature Selection](#FeatureSelection)
# * [Feature Engineering](#FeatureEngineering)
#     * [Variable Types](#VariableTypes)
#     * [Variable Characteristics](#VariableCharacteristics)
#     * [Missind Data Imputation](#MissindDataImputation)
#     * [Categorical Variable Encoding](#CategoricalVariableEncoding)
#     * [Variable Discretisation (Binning)](#Binning)
#     * [Outlier Handling](#OutlierHandling)
#     * [Feature Scaling](#FeatureScaling)
#     * [Standardization and Normalization](#StandardizationNormalization)
#
#
#
#
#
#
#
#
#
#
#
# https://www.geeksforgeeks.org/how-to-add-a-table-of-contents-in-the-jupyter-notebook/

# %% [markdown]
# # Feature Selection <a name="FeatureSelection"></a>

# %% [markdown]
# https://www.kaggle.com/code/carlmcbrideellis/feature-selection-using-the-boruta-shap-package

# %% [markdown]
# https://www.kaggle.com/code/prashant111/comprehensive-guide-on-feature-selection

# %%
from sklearn.feature_selection import f_regression

#fregression(X,y)
#p_values = f_regression(X,y)[1] # 0 is Fstats and 1 is p-values
#p_values #P-values are calculates like this: if [x1,x2,x3] -> y the p-value=[X1toY,X2toY, X3toY], if P-valie <0.5 then significant else insignificant

# %% [markdown]
# # Feature Engineering <a name="FeatureEngineering"></a>
#
# Feature Engineering is the process of usingdomain knowledge to extract features from raw data via data mining techniques. It is always data and domain dependent.

# %% [markdown]
# #### Feature Engine is the king
# - https://feature-engine.readthedocs.io/en/1.0.x/quickstart.html
# - Feature-engine’s transformers can be assembled within a Scikit-learn pipeline. This way, we can store our feature engineering pipeline in one object and save it in one pickle (.pkl).

# %% [markdown]
# - All Notebooks: https://github.com/solegalli/feature-engineering-for-machine-learning

# %% [markdown]
# https://tigeranalytics.udemy.com/course/feature-engineering-for-machine-learning/

# %% [markdown]
# <ul>
#     <li><strong>Variable Types</strong></li>
#     <li><strong>Variable Characteristics</strong></li>
#     <li><strong>Missind Data Imputation</strong>
#         <ul>
#             <li>Lost--Doesn't Exists--Not found/Identified</li>
#             <li>MCAR(Missing data Completely At Random) -- MAR(Missing data At Random) -- MNAR(Missing data Not At Random)</li>
#         </ul>
#     </li>
#     <li><strong>Multivariate Missing Data Imputation</strong></li>
#     <li><strong>Categorical Variable Encoding</strong></li>
#     <li><strong>Variable Transformation</strong></li>
#     <li><strong>Variable Discretisation</strong></li>
#     <li><strong>Outlier Handling</strong></li>
#     <li><strong>Feature Scaling</strong></li>
#     <li><strong>Engineering Mixed Variable</strong></li>
#     <li><strong>Engineering Date Time Variable</strong></li>
#     <li><strong>Assembling Feature Engineering Pipeline</strong></li>
# </ul>

# %% [markdown]
# <a name="VariableTypes"></a><h1>Variable Types</h1>

# %% [markdown]
# https://expertseoinfo.com/what-is-variable-what-are-the-types-of-variables/

# %% [markdown]
# ![types-of-variable.webp](attachment:types-of-variable.webp)

# %% [markdown]
# Mixed variable
# - some numeric some categorical
# - number and character in same record

# %% [markdown]
# <a name="VariableCharacteristics"><h1>Variable Characteristics</h1>

# %% [markdown]
# <ol>
#     <li><strong>Cardinality (No. of unique label)</strong>
#         <ul>
#             <li><strong>High Cardinality & Rare labels:</strong> Overfitting & Opetarionalisation problems</li>
#             <li><strong>Low Cardinality:</strong> Improve model performance</li>
#             <li><strong>Rare Labels:</strong> Hard to understand the impact of rare labels on model performance/ outcome</li>
#         </ul>
#     </li>
# </ol>

# %% [markdown]
# <ol start=2>
#     <li><strong>Linear Model Assumptions</strong>
#         <ul>
#             <li><strong>Linearity:</strong> Linear relation between predictors and target.</li>
#             <li><strong>No perfect multicolinearoty:</strong> No perfect linear relation between two or more predictors.</li>
#             <li><strong>Normally distributed errors:</strong> The residuals are random, normally distributed with a mean of 0.</li>
#             <li><strong>Homoscedasticity:</strong> At each level of predictorvariables, the variance of residual terms should be constant.
#                 <ul>
#                     <li><strong>Residuals plot</strong></li>
#                     <li><strong>Levene's test</strong></li>
#                     <li><strong>Barlett's test</strong></li>
#                     <li><strong>Goldfeld-Quandt test</strong></li>
#                 </ul></li>
#             <li><strong>AVOIDE:</strong> Outliers, lack of Homoscedasticity and too skewed variables</li>
#                 <ul>
#                     <li><strong>Mathematical Transformation</strong></li>
#                     <li><strong>Discretisation</strong></li>
#                     <li><strong>Remove outliers</strong></li>
#                 </ul>
#         </ul>
#     </li>
# </ol>

# %% [markdown]
# <ol start=3>
#     <li><strong>Variable Distribution</strong>
#         <ul>
#             <li><strong>Assuming Normality</strong></li>
#             <li><strong>Variable Transformation</strong></li>
#             <ul>
#                     <li><strong>Logarithmic</strong></li>
#                     <li><strong>Exponential</strong></li>
#                     <li><strong>Reciprocal</strong></li>
#                     <li><strong>Box-Cox</strong></li>
#              </ul>
#             <li><strong>Discretisation</strong></li>
#             <ul>
#                     <li><strong>Equal width bins</strong></li>
#                         <ul>
#                                 <li><strong>Bins = (max-min)/n bins</strong></li>
#                                 <li><strong>Does not improve spread</strong></li>
#                         </ul>
#                     <li><strong>Equal frequency bins</strong></li>
#                         <ul>
#                                 <li><strong>Bins determined by quantiles</strong></li>
#                                 <li><strong>Equal numbers of  observations per bins</strong></li>
#                                 <li><strong>Generally improves spread</strong></li>
#                         </ul>
#             </ul>
#         </ul>
#     </li>
# </ol>

# %% [markdown]
# ![Relationship_between_mean_and_median_under_different_skewness.png](attachment:Relationship_between_mean_and_median_under_different_skewness.png)

# %% [markdown]
# By Diva Jain - https://codeburst.io/2-important-statistics-terms-you-need-to-know-in-data-science-skewness-and-kurtosis-388fef94eeaa, CC BY-SA 4.0, https://commons.wikimedia.org/w/index.php?curid=84219892

# %% [markdown]
# <ol start=4>
#     <li><strong>Outliers</strong>
#         <ul>
#             <li><strong>Outliers Formula:</strong></li>
#                 <ul>
#                         <li><strong>Normal Distribution:</strong> Values outside  <code>mean +- 3 x Standard Daviations</code> are consider outliers.</li>
#                         <li><strong>Skewed Distribution:</strong> Using IQR(Inter-quantile range)</li>
#                             <ul>
#                                 <li><strong>IQR:</strong> 75th Quantile - 25th Quantile = 3rd Quartile - 1st Quartile</li>
#                                 <li><strong>Upper Limit:</strong> 75th Quantile + IQR x 1.5</li>
#                                 <li><strong>Lower Limit:</strong> 25th Quantile - IQR x 1.5</li>
#                                 <li><strong>Extreme Case:</strong> Multiply IQR by 3 instead of 1.5</li>
#                             </ul>
#                         <li><strong>Vizualization:</strong> Using Box plot</li>
#                 </ul>
#             <li><strong>Algorithm suseceptable to outliers</strong></li>
#                 <ul>
#                         <li><strong>Linear models</strong></li>
#                         <li><strong>Adaboost</strong></li>
#                 </ul>
#             <li><strong>Low Cardinality:</strong> Improve model performance</li>
#             <li><strong>Rare Labels:</strong> Hard to understand the impact of rare labels on model performance/ outcome</li>
#         </ul>
#     </li>
# </ol>

# %% [markdown]
# <ol start=5>
#     <li><strong>Variable Magnitude</strong>
#         <ul>
#             <li>Variable with bigger magnitude / value range <strong>dominates</strong> over the ones with smaller magnitude/value range.</li>
#             <li>Regression coffecient is influenced by magnitude</li>
#             <li>Gradient Decent converges faster if magnitude are on similar scale</li>
#             <li>SVM takes less time if feature scaling is used</li>
#             <li><strong>Euclidean distance</strong> are sensitiveto feature magnitude</li>
#             <li><strong>ML Models</strong> that are <strong>sensitive</strong> to feature magnitude</li>
#                 <ul>
#                     <li>Liner and Logistic Regression</li>
#                     <li>Neural Networks</li>
#                     <li>SVM</li>
#                     <li>KNN</li>
#                     <li>K-means clustering</li>
#                     <li>Liner Discriminant Analysis (LDA)</li>
#                     <li>Principal Component Analysis (PCA)</li>
#                 </ul>
#             <li><strong>ML Models</strong> that are <strong>insensitive</strong> to feature magnitude</li>
#                 <ul>
#                     <li>Classification and Regression Trees</li>
#                     <li>Random Forests</li>
#                     <li>Gradient Boosted Trees</li>
#                 </ul>
#         </ul>
#     </li>
# </ol>

# %% [markdown]
# <a name="MissindDataImputation"></a><h1>Missind Data Imputation</h1>

# %% [markdown]
# <ol>
#     <li><strong>Complete Case Analysis:</strong>
#         <ul>
#             <li>Data is missing completely at randome</li>
#             <li>Delete all records with missing data</li>
#             <li>No more than 5% of total dataset contains missing data</li>
#         </ul>
#     </li>
#     <li><strong>Mean and Median imputation:</strong>
#         <ul>
#             <li>Data is missing completely at randome</li>
#             <li>The missing data mostlikely looks like majority of the observations</li>
#             <li>Hire percentage of NA results in higher distortation of distribution and varience (IQR increases due to imputation =leads to=> an apparent increase in outliers as Vickers narrows)</li>
#             <li>No more than 5% of variable contains missing data</li>
#             <li>Sometimes used along with missing_indicator_flag</li>
#         </ul>
#     </li>
#     <li><strong>Mode imputation:</strong>
#         <ul>
#             <li>Data is missing completely at randome</li>
#             <li>No more than 5% of variable contains missing data</li>
#             <li>The missing data most likely looks like majority of the observations</li>
#             <li>Hire percentage of NA results in higher distortation</li>
#             <li>Over representation of majorioty class/value</li>
#         </ul>
#     </li>
#     <li><strong>Arbitrary Value imputation:</strong>
#         <ul>
#             <li><strong>Numerical:</strong>0,-1,999,-999; <strong>Categorical:</strong>"MISSING","UNKNOWN","NA",..</li>
#             <li>Edge values of distributions, not in middle</li>
#             <li>Data is not missing at randome</li>
#             <li>Hire percentage of NA results in higher distortation</li>
#                 <li>Makes it look like there are less outliers</li>
#             <li>Ok for tree Algo but not ok for linear models</li>
#             <li>End of distribution imputation (Only for numerical variable, impute using value at the end of distribution)</li>
#                 <ul>
#                     <li>Mean +- ( {3 or 1.5} x SD)</li>
#                     <li>Masks outliers, affects varience</li>
#                 </ul>
#         </ul>
#     </li>
#     <li><strong>Randome Sample imputation:</strong>
#         <ul>
#             <li>Filling the missing data with values selected completely at randome from the available observed values</li>
#         </ul>
#     </li>
# </ol>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# https://www.kaggle.com/datasets/dansbecker/melbourne-housing-snapshot
df = pd.read_csv("./resources/melb_data.csv")
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
def percent_null(df):
    per_null = (100*df.isnull().sum())/len(df)
    per_null.sort_values(ascending=False,inplace=True)
    return per_null

null_info_df=percent_null(df)
null_info_df
# Out:
# BuildingArea     47.496318
# YearBuilt        39.580265
# CouncilArea      10.081001
# Car               0.456554
# Suburb            0.000000
# Bathroom          0.000000
# Regionname        0.000000
# Longtitude        0.000000
# Lattitude         0.000000
# Landsize          0.000000
# Bedroom2          0.000000
# Address           0.000000
# Postcode          0.000000
# Distance          0.000000
# Date              0.000000
# SellerG           0.000000
# Method            0.000000
# Price             0.000000
# Type              0.000000
# Rooms             0.000000
# Propertycount     0.000000
# dtype: float64

# %%
sns.barplot(x=null_info_df.index,y=null_info_df)
plt.xticks(rotation=90)
plt.show()

# %%
df[df['Car'].isnull()]
# Out:
#                 Suburb            Address  Rooms Type      Price Method  \
# 12221       Ascot Vale     132 The Parade      3    h   985000.0      S
# 12247   Brunswick East        18 Ethel St      2    h  1023000.0      S
# 12259     Clifton Hill      34 Fenwick St      3    h  1436000.0      S
# 12320    Glen Waverley      19 Diamond Av      3    h  1370000.0      S
# 12362          Newport  11 Collingwood Rd      4    h  1180000.0     PI
# ...                ...                ...    ...  ...        ...    ...
# 13496     Moonee Ponds     46 Eglinton St      4    h  1525000.0      S
# 13508  North Melbourne       9 Erskine St      2    h  1080000.0      S
# 13522   Port Melbourne      201 Stokes St      2    h  1515000.0     SP
# 13524          Prahran   17 Packington Pl      2    h  1365000.0      S
# 13550   Sunshine North     5 Berkshire Rd      3    h   595000.0     SP
#
#          SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
df.dropna(axis=0, subset=['Car','CouncilArea']).isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea     5765
# YearBuilt        4763
# CouncilArea         0
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html
df[['Car','CouncilArea']].fillna(value=0).isnull().sum()
# Out:
# Car            0
# CouncilArea    0
# dtype: int64

# %%
df['BuildingArea']

# %% [markdown]
# <a name="CategoricalVariableEncoding"></a><h1>Categorical Variable Encoding</h1>

# %% [markdown]
# <h3>Categorical Variable Encoding Techniques</h3>

# %% [markdown]
# <ol>
#     <li>Traditional techniques</li>
#         <ol>
#             <li>One hot encoding</li>
#             <li>Count / Frequency encoding</li>
#             <li>Ordinal / Label encoding</li>
#         </ol>
#     <li>Monotonic relationship</li>
#         <ol>
#             <li>Ordinal label encoding</li>
#             <li>Mean encoding</li>
#             <li>Weight of evidence</li>
#         </ol>
#     <li>Alternative techniques</li>
#         <ol>
#             <li>Binary encoding</li>
#             <li>Feature hashing</li>
#             <li>Others</li>
#         </ol>
# </ol>

# %%
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
# Here, for a categorical variable there are N distinct possible values the the drop_first=True argument will create N-1 dummy variable 
# (one-hot-encodeing). And the coeff/weight value drived by the model will be benchmarked based on the removed one.
pd.get_dummies(df,drop_first=True)
# Out:
#        Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 0          2  1480000.0       2.5    3067.0       2.0       1.0  1.0
# 1          2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2          3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 3          3   850000.0       2.5    3067.0       3.0       2.0  1.0
# 4          4  1600000.0       2.5    3067.0       3.0       1.0  2.0
# ...      ...        ...       ...       ...       ...       ...  ...
# 13575      4  1245000.0      16.7    3150.0       4.0       2.0  2.0
# 13576      3  1031000.0       6.8    3016.0       3.0       2.0  2.0
# 13577      3  1170000.0       6.8    3016.0       3.0       2.0  4.0
# 13578      4  2500000.0       6.8    3016.0       4.0       1.0  5.0
# 13579      4  1285000.0       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt  ...  CouncilArea_Wyndham  \
# 0         202.0           NaN        NaN  ...                False
# ...

# %%
# Integer encodeing 
#  Mild Hot Fire ==> 1 2 3
# CAN USA MEX ==> N/A - One hot encoding make sense

# %% [markdown]
# <a name="Binning"></a><h1>Variable Discretisation (Binning)</h1>

# %% [markdown]
# <a name="OutlierHandling"></a><h1>Outlier Handling</h1>

# %% [markdown]
# <h3>Effects of Outliers in data</h3>
# - All linear models and AdaBoost techinques are affected by outliers in the data

# %% [markdown]
# <h3>Detecting Outliers in data</h3>

# %% [markdown]
# <ol>
#     <li><strong>Gaussian distribution (mean and std):</strong>
#         <ul>
#             <li><strong>Normal distribution:</strong> For Normal distribution <strong>~99%</strong> of observations are within <strong>mean +- 3 x Standard Deviations</strong>, so values outside are considered outliers</li>
#         </ul>
#     </li>
#     <li><strong>Inter-quantal range proximity rule:</strong></li>
#         <ul>
#             <li>For <strong>NON Normal distribution</strong>  we need to calculate Inter-quantile range (IQR) and the quantiles,as follow: </li>
#             <li>IQR = 75th Quantile - 25th Quantile</li>
#             <li><strong>Upper Limit = 75th Quantile + IQR x 1.5</strong></li>
#             <li><strong>Lower Limit = 25th Quantile - IQR x 1.5</strong></li>
#             <li>So the values outside of upper and lower limit are considered outliers.</li>
#             <li><strong>NOTE:</strong> for extreme outliers, multiply the IQR by 3 instead of 1.5</li>
#         </ul>
#     <li><strong>Quantiles:</strong></li>
#         <ul>
#             <li>For <strong>Normal distribution</strong> we need to calculate the 5th quantile and 95th quantile</li>
#             <li>There is ~95% of data above 5th quantile and there is ~95% of data below 95th quantile.</li>
#             <li>So the values outside of <strong>5th quantile and 95th quantile</strong> are considered outliers.</li>
#         </ul>
# </ol>

# %% [markdown]
# <h3>Handling Outliers Techniques</h3>

# %% [markdown]
# <ol>
#     <li><strong>Trimming:</strong>
#         <ul>
#             <li>Detect & remove outliers from data (Delete rows).</li>
#             <li> Outliers are rare so theoritically very less % of data is deleted.</li>
#             <li><strong>Pro: </strong> simple and fase</li>
#             <li><strong>Cons: </strong> Big chunk of data is removed if outliers are more.</li>
#         </ul>
#     </li>
#     <li><strong>Missing Data:</strong>
#         <ul>
#             <li>Assume the outlier value is missing (set as NAN)</li>
#             <li>Use missing data imputaion on those values</li>
#         </ul>
#     </li>
#         <li><strong>Descritization:</strong>
#         <ul>
#             <li>Put outliers in lower or upper bins </li>
#             <li>Just like descritization/binning but a column have only one bin</li>
#         </ul>
#     </li>
#     <li><strong>Censoring:</strong>
#         <ul>
#             <li>Capping
#                 <ul>
#                     <li>Cap minimun and maximum for a perticular variable</li>
#                     <li>So replace outlier(extreme values) with border values</li>
#                     <li><strong>Pro: </strong> No data is removed</li>
#                     <li><strong>Cons: </strong> Variable distribution is distorted</li>
#                 </ul></li>
#             <li>Top / Bottom coding </li>
#             <li>Winsorization (SkLearn Feature-engine) - [Pending]</li>
#         </ul>
#     </li>
# </ol>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()


def create_ages(mu=50,sigma=13, num_samples=1000, seed=42):
    np.random.seed(seed)
    sample_ages=np.random.normal(loc=mu, scale=sigma,size=num_samples)
    sample_ages=np.round(sample_ages,decimals=0)
    return sample_ages

age_data=create_ages()
df = pd.DataFrame(data= age_data,columns=['Age'])
df['Age'] =df['Age'].astype(int)
df
# Out:
#      Age
# 0     56
# 1     48
# 2     58
# 3     70
# 4     47
# ..   ...
# 995   46
# 996   73
# 997   58
# 998   43
# 999   57
#
# [1000 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     1000 non-null   int32
# dtypes: int32(1)
# memory usage: 4.0 KB

# %%
sns.displot(df['Age'])
# Out:
# C:\Users\rushi\.conda\envs\NativeLearning\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#                Age
# count  1000.000000
# mean     50.256000
# std      12.734152
# min       8.000000
# 25%      42.000000
# 50%      50.000000
# 75%      58.000000
# max     100.000000

# %%
print('25%::',df['Age'].quantile(0.25),'50%',df['Age'].quantile(0.5),'75%',df['Age'].quantile(0.75))
print('25%::',np.quantile(df['Age'], 0.25),'50%',np.quantile(df['Age'], 0.5),'75%',np.quantile(df['Age'], 0.75))
# Out:
# 25%:: 42.0 50% 50.0 75% 58.0
# 25%:: 42.0 50% 50.0 75% 58.0

# %%
# For outlier elimination we can eliminate 1% of data
Upper_Limit=df['Age'].quantile(0.99)
Filtered_df = df[df['Age']<Upper_Limit]
Filtered_df=Filtered_df.reset_index(drop=True)
Filtered_df
# Out:
#      Age
# 0     56
# 1     48
# 2     58
# 3     70
# 4     47
# ..   ...
# 985   46
# 986   73
# 987   58
# 988   43
# 989   57
#
# [990 rows x 1 columns]

# %% [markdown]
# <a name="FeatureScaling"></a><h1>Feature Scaling</h1>

# %% [markdown]
# <h3>Effects of data scaling</h3>
#
# - The regression coefficient is directly influenced by the scale of variable
# - Pending

# %% [markdown]
# <h3>Scaling methods</h3>
#
# <ol>
#     <li><strong>Standardisation:</strong>
#         <ul>
#             <li></li>
#         </ul>
#     </li>
#     <li><strong>Mean normalisation:</strong></li>
#     <li><strong>Scaling to maximum and minimum:</strong></li>
#     <li><strong>Scaling to absolute maximum:</strong></li>
#     <li><strong>Scaling to median and quantiles:</strong></li>
#     <li><strong>Scaling to  unit norm:</strong></li>
# </ol>

# %% [markdown]
# <a name="StandardizationNormalization"></a># Standardization and Normalization

# %% [markdown]
# A Note on Normalization
# As explained in the lesson, the concept 'normalization' has different meanings in different contexts.
#
# There are two materials which we find particularly useful:
#
# 1) The Wikipedia article on Feature scaling: https://en.wikipedia.org/wiki/Feature_scaling
#
# 2) This article on L1-norm and L2-norm: http://www.chioka.in/differences-between-the-l1-norm-and-the-l2-norm-least-absolute-deviations-and-least-squares/

# %%
from sklearn.preprocessing import StandardScaler
scaler_obj = StandardScaler()
# scaler_obj.fit(X_train)
# X_train_scaled = scaler_obj.transform(X_train)
## Or
# X_train_scaled = scaler_obj.fit_transform(X_train)

# %% [markdown]
# # Assumotions

# %%
# Linearity -> Data is exponential and we want to make it liner then use LOG function
#df['log_col_name'] = np.log(df['col_name'])
# Restore var
# np.exp(df['log_col_name'])

# %%
# Check Multicolinearity
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
#vif['VIF']=[variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
#vif["features"] = df.columns
# vif

# %% [markdown]
# # Regularization in Machine Learning

# %% [markdown]
# ## Model Assumptions

# %% [markdown]
# # Model Selection

# %% [markdown]
# # DATA PROFILING

# %% [markdown]
# Data profiling typically constitutes the
# - missing/outlier checks,
# - primary key identification,
# - Then univariate,
# - bivariate analyses

# %% [markdown]
# ## f

# %% [markdown]
# What most people are wondering is not 'when do we have multicollinearity' as we usually do have some.
#
# The better question to ask is 'When can we safely ignore multicollinearity'.
#
# Here's a great article on the topic: http://statisticalhorizons.com/multicollinearity
#
# ***
#
# Regarding the variance inflation factor method that we employed from StatsModels, you can read the full documentation here: https://www.statsmodels.org/stable/generated/statsmodels.stats.outliers_influence.variance_inflation_factor.html
#
# Best,
# The 365 Team
